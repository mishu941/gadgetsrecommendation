# %%
import pandas as pd
import numpy as np

data = pd.read_csv('laptops.csv')


data.shape
# Out:
# (5026, 29)

# %%
data.columns
# Out:
# Index(['Brand', 'Model', 'Image', 'Price', 'RAM', 'Size', 'SSD', 'Colours',
#        'Operating system', 'Hard disk', 'Model Number', 'Processor',
#        'Graphic card', 'Dedicated Graphics', 'Finger Print Sensor',
#        'Resolution', 'Wi-Fi standards supported', 'Weight(kg)',
#        'Dimensions(mm)', 'Series', 'Touch Screen', 'Base Clock Speed',
#        'Graphics Processor', 'Product', 'Dedicated Graphics.1', 'HDMI Port',
#        'Battery life', 'Dedicated Graphic Memory Type',
#        'Expandable RAM up to (GB)'],
#       dtype='object')

# %%
data.head(5)
# Out:
#       Brand                Model  \
# 0  Micromax            In Note 1
# 1        HP  Pavilion 15-ab205tx
# 2        HP  Pavilion 15-AU626TX
# 3      Asus        R558UQ-DM539D
# 4        HP               240 G4
#
#                                                Image     Price   RAM  \
# 0  https://i.gadgets360cdn.com/products/large/mic...  ₹ 10,999   4GB
# 1  https://i.gadgets360cdn.com/products/laptops/l...  ₹ 49,790   4GB
# 2  https://i.gadgets360cdn.com/products/laptops/l...  ₹ 69,980  16GB
# 3  https://i.gadgets360cdn.com/products/laptops/l...  ₹ 35,490   4GB
# 4  https://i.gadgets360cdn.com/products/laptops/l...  ₹ 27,500   4GB
#
#          Size  SSD            Colours Operating system Hard disk  ...  \
# 0         NaN  NaN       Green, White       Android 10       NaN  ...
# 1  15.60-inch   No     Natural Silver  Windows 10 Home       1TB  ...
# 2  15.60-inch   No             Silver       Windows 10       2TB  ...
# ...

# %%
data = data.loc[:,['Product','Image','Brand','Processor','RAM','Hard disk','SSD','Graphic card','Operating system','Resolution','Dimensions(mm)', 'Weight(kg)','Battery life' ,'Price']]

data.head(10)
# Out:
#                                              Product  \
# 0         Micromax In Note 1 (4GB RAM, 64GB) - White
# 1  HP Pavilion 15-AB205TX Laptop (Windows 10, 4GB...
# 2  HP Pavilion 15-AU626TX Laptop (Windows 10, 16G...
# 3  Asus R558UQ-DM539D Laptop (DOS, 4GB RAM, 1000G...
# 4  HP 240 G4 Laptop (DOS, 4GB RAM, 500GB HDD, Int...
# 5                                                NaN
# 6  Acer Aspire E E1-572G Laptop (Windows 8.1, 8GB...
# 7  Dell Inspiron 3000 3543 Laptop (Linux, 4GB RAM...
# 8  Asus X550LC-XX119H Laptop (Windows 8, 4GB RAM,...
# 9  HP Pavilion 15-AU020TX Laptop (Windows 10, 4GB...
#
#                                                Image     Brand  \
# 0  https://i.gadgets360cdn.com/products/large/mic...  Micromax
# 1  https://i.gadgets360cdn.com/products/laptops/l...        HP
# 2  https://i.gadgets360cdn.com/products/laptops/l...        HP
# 3  https://i.gadgets360cdn.com/products/laptops/l...      Asus
# ...

# %%
#data.to_csv('ALL_LAPTOPS.csv',index=False)

# %%
df=pd.read_csv('ALL_LAPTOPS.csv')
df.shape
# Out:
# (5026, 14)

# %%
df.isnull().sum()
# Out:
# Product             1834
# Image                  0
# Brand                  0
# Processor            226
# RAM                   71
# Hard disk            208
# SSD                  108
# Graphic card        1736
# Operating system     143
# Resolution           871
# Dimensions(mm)      1222
# Weight(kg)          1107
# Battery life        3212
# Price               1834
# dtype: int64

# %%
df.dropna(inplace=True)
df.shape
# Out:
# (752, 14)

# %%
df.columns
# Out:
# Index(['Product', 'Image', 'Brand', 'Processor', 'RAM', 'Hard disk', 'SSD',
#        'Graphic card', 'Operating system', 'Resolution', 'Dimensions(mm)',
#        'Weight(kg)', 'Battery life', 'Price'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Product             0
# Image               0
# Brand               0
# Processor           0
# RAM                 0
# Hard disk           0
# SSD                 0
# Graphic card        0
# Operating system    0
# Resolution          0
# Dimensions(mm)      0
# Weight(kg)          0
# Battery life        0
# Price               0
# dtype: int64

# %%
#df.to_csv('C_LAPTOPS.csv',index=False)

# %%
d=pd.read_csv('C_LAPTOPS.csv')

# %%
d.shape
# Out:
# (752, 14)

# %%
d.isnull().sum()
# Out:
# Product             0
# Image               0
# Brand               0
# Processor           0
# RAM                 0
# Hard disk           0
# SSD                 0
# Graphic card        0
# Operating system    0
# Resolution          0
# Dimensions(mm)      0
# Weight(kg)          0
# Battery life        0
# Price               0
# dtype: int64
